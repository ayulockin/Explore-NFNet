# %% [markdown]
# <a href="https://colab.research.google.com/github/ayulockin/Explore-NFNet/blob/main/Effect_of_Batch_Normalization_on_Learning_Rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧰 Setups, Installations and Imports

# %%
# %%capture
# !pip install wandb

# %%
# deep learning imports
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.datasets import cifar10

# regular imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Seed everything for reproducibility
def seed_everything():
    # Set the random seeds
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1' 
    np.random.seed(hash("improves reproducibility") % 2**32 - 1)
    tf.random.set_seed(hash("by removing stochasticity") % 2**32 - 1)

seed_everything()

# experiment tracking imports
import wandb
from wandb.keras import WandbCallback

wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# # ⛄ Download and Prepare Dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
CLASS_NAMES = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

print('Shape of x_train: ', x_train.shape)
print('Shape of y_train: ', y_train.shape)
print('Shape of x_test: ', x_test.shape)
print('Shape of y_test: ', y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# Shape of x_train:  (50000, 32, 32, 3)
# Shape of y_train:  (50000, 1)
# Shape of x_test:  (10000, 32, 32, 3)
# Shape of y_test:  (10000, 1)

# %% [markdown]
# # 🐾 Dataloader

# %%
AUTO = tf.data.experimental.AUTOTUNE
BATCH_SIZE = 64
IMG_SHAPE = 32
CHANNELS = 3
NUM_CLASSES = 10
EPOCHS = 100

# %%
@tf.function
def preprocess_image(image, label):
  image = tf.cast(image, tf.float32)
  image = image/255.0
  return image, label

# %%
trainloader = tf.data.Dataset.from_tensor_slices((x_train, y_train))
testloader = tf.data.Dataset.from_tensor_slices((x_test, y_test))

trainloader = (
    trainloader
    .shuffle(1024)
    .map(preprocess_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

testloader = (
    testloader
    .map(preprocess_image, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# %%
# Ref: https://www.tensorflow.org/tutorials/load_data/images
def show_batch(image_batch, label_batch):
  plt.figure(figsize=(10,10))
  for n in range(25):
      ax = plt.subplot(5,5,n+1)
      plt.imshow(image_batch[n])
      plt.title(CLASS_NAMES[int(label_batch[n])])
      plt.axis('off')

image_batch, label_batch = next(iter(trainloader))
print(image_batch.shape, label_batch.shape)

show_batch(image_batch, label_batch)
# Out:
# (64, 32, 32, 3) (64, 1)

# %% [markdown]
# # 📲 Callbacks

# %%
earlystopper = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=0, mode='auto',
    restore_best_weights=True
)

# %% [markdown]
# # 😥 Without BN With LR 0.01

# %% [markdown]
# #### Model

# %%
def ModelnoBN():
  inputs = keras.layers.Input(shape=(IMG_SHAPE, IMG_SHAPE, CHANNELS))

  x = keras.layers.Conv2D(filters=32,
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(inputs)
  x = keras.activations.relu(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.activations.relu(x)

  x = keras.layers.MaxPooling2D(pool_size=2)(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.activations.relu(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.activations.relu(x)

  x = keras.layers.GlobalAveragePooling2D()(x)

  x = keras.layers.Dense(128, activation='relu')(x)
  x = keras.layers.Dense(32, activation='relu')(x)
  
  outputs = keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

  return keras.models.Model(inputs=inputs, outputs=outputs)

tf.keras.backend.clear_session()
model = ModelnoBN()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# tf.nn.relu (TFOpLambda)      (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)    (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 32)        9248
# _________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)    (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        9248
# _________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)    (None, 10, 10, 32)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 37,322
# Trainable params: 37,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 🚋 Train with W&B

# %%
tf.keras.backend.clear_session()
# Intialize model
model = ModelnoBN()

opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(opt, 'sparse_categorical_crossentropy', metrics=['acc'])

# Intialize W&B run
run = wandb.init(entity='ayush-thakur', project='nfnet', job_type='bn-exploration')

# Train model
model.fit(trainloader,
          epochs=EPOCHS,
          validation_data=testloader,
          callbacks=[WandbCallback(),
                     earlystopper])  

# Evaluate model on test set
loss, acc = model.evaluate(testloader)
wandb.log({'Test Accuracy': round(acc, 3)})

# Close W&B run
run.finish()
# Out:
# wandb: Currently logged in as: ayush-thakur (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">prime-plasma-75</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ayush-thakur/nfnet" target="_blank">https://wandb.ai/ayush-thakur/nfnet</a><br/>
#                 Run page: <a href="https://wandb.ai/ayush-thakur/nfnet/runs/39z29au4" target="_blank">https://wandb.ai/ayush-thakur/nfnet/runs/39z29au4</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210305_125512-39z29au4</code><br/><br/>
# Epoch 1/100
#   6/782 [..............................] - ETA: 19s - loss: 2.3482 - acc: 0.1135WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0104s vs `on_train_batch_end` time: 0.0125s). Check your callbacks.
# 782/782 [==============================] - 42s 16ms/step - loss: 2.3055 - acc: 0.0969 - val_loss: 2.3034 - val_acc: 0.1000
# Epoch 2/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0954 - val_loss: 2.3033 - val_acc: 0.1000
# Epoch 3/100
# 782/782 [==============================] - 12s 15ms/step - loss: 2.3039 - acc: 0.0987 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 4/100
# 782/782 [==============================] - 12s 15ms/step - loss: 2.3038 - acc: 0.0980 - val_loss: 2.3036 - val_acc: 0.1000
# Epoch 5/100
# 782/782 [==============================] - 11s 14ms/step - loss: 2.3039 - acc: 0.0946 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 6/100
# 782/782 [==============================] - 11s 14ms/step - loss: 2.3039 - acc: 0.0977 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 7/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0956 - val_loss: 2.3037 - val_acc: 0.1000
# Epoch 8/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3037 - acc: 0.0976 - val_loss: 2.3036 - val_acc: 0.1000
# Epoch 9/100
# 782/782 [==============================] - 12s 15ms/step - loss: 2.3038 - acc: 0.0983 - val_loss: 2.3034 - val_acc: 0.1000
# Epoch 10/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0965 - val_loss: 2.3037 - val_acc: 0.1000
# Epoch 11/100
# 782/782 [==============================] - 12s 15ms/step - loss: 2.3039 - acc: 0.0975 - val_loss: 2.3038 - val_acc: 0.1000
# Epoch 12/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3039 - acc: 0.0974 - val_loss: 2.3032 - val_acc: 0.1000
# Epoch 13/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0971 - val_loss: 2.3037 - val_acc: 0.1000
# Epoch 14/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3039 - acc: 0.0956 - val_loss: 2.3033 - val_acc: 0.1000
# Epoch 15/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0977 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 16/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3037 - acc: 0.0986 - val_loss: 2.3038 - val_acc: 0.1000
# Epoch 17/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3037 - acc: 0.0983 - val_loss: 2.3038 - val_acc: 0.1000
# Epoch 18/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0976 - val_loss: 2.3036 - val_acc: 0.1000
# Epoch 19/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3038 - acc: 0.0987 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 20/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3036 - acc: 0.0987 - val_loss: 2.3035 - val_acc: 0.1000
# Epoch 21/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3036 - acc: 0.0990 - val_loss: 2.3037 - val_acc: 0.1000
# Epoch 22/100
# 782/782 [==============================] - 11s 15ms/step - loss: 2.3037 - acc: 0.0980 - val_loss: 2.3035 - val_acc: 0.1000
# 157/157 [==============================] - 1s 5ms/step - loss: 2.3032 - acc: 0.1000
# <br/>Waiting for W&B process to finish, PID 156<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.50MB of 0.50MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210305_125512-39z29au4/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210305_125512-39z29au4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>2.30366</td></tr><tr><td>acc</td><td>0.09774</td></tr><tr><td>val_loss</td><td>2.30353</td></tr><tr><td>val_acc</td><td>0.1</td></tr><tr><td>_runtime</td><td>288</td></tr><tr><td>_timestamp</td><td>1614949200</td></tr><tr><td>_step</td><td>22</td></tr><tr><td>best_val_loss</td><td>2.30321</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>Test Accuracy</td><td>0.1</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▃▃▅▄▂▂▂▂▃▃▅▄▂▂▃▄▁▁▂</td></tr><tr><td>acc</td><td>▃▄██▃▆▂▃▄▅▇▇▁▂▄▄▆▆▃▆▆▅</td></tr><tr><td>val_loss</td><td>▃▂▅▅▄▄▇▆▄▇█▁▆▂▅██▅▄▅▇▅</td></tr><tr><td>val_acc</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 2 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">prime-plasma-75</strong>: <a href="https://wandb.ai/ayush-thakur/nfnet/runs/39z29au4" target="_blank">https://wandb.ai/ayush-thakur/nfnet/runs/39z29au4</a><br/>

# %% [markdown]
# # 😉 BN With LR 0.01

# %% [markdown]
# #### Model

# %%
def ModelBN():
  inputs = keras.layers.Input(shape=(IMG_SHAPE, IMG_SHAPE, CHANNELS))

  x = keras.layers.Conv2D(filters=32,
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(inputs)
  x = keras.layers.BatchNormalization()(x)
  x = keras.activations.relu(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.activations.relu(x)

  x = keras.layers.MaxPooling2D(pool_size=2)(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.activations.relu(x)

  x = keras.layers.Conv2D(filters=32, 
                          kernel_size=(3,3),
                          strides=(1,1),
                          padding='valid')(x)
  x = keras.layers.BatchNormalization()(x)
  x = keras.activations.relu(x)

  x = keras.layers.GlobalAveragePooling2D()(x)

  x = keras.layers.Dense(128, activation='relu')(x)
  x = keras.layers.Dense(32, activation='relu')(x)
  
  outputs = keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)

  return keras.models.Model(inputs=inputs, outputs=outputs)

tf.keras.backend.clear_session()
model = ModelBN()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 30, 30, 32)        128
# _________________________________________________________________
# tf.nn.relu (TFOpLambda)      (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)    (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 12, 12, 32)        128
# _________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)    (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 10, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 10, 10, 32)        128
# _________________________________________________________________
# tf.nn.relu_3 (TFOpLambda)    (None, 10, 10, 32)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 128)               4224
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                330
# =================================================================
# Total params: 37,834
# Trainable params: 37,578
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# ## 🚋 Train with W&B

# %%
tf.keras.backend.clear_session()
# Intialize model
model = ModelBN()

opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(opt, 'sparse_categorical_crossentropy', metrics=['acc'])

# Intialize W&B run
run = wandb.init(entity='ayush-thakur', project='nfnet', job_type='bn-exploration')

# Train model
model.fit(trainloader,
          epochs=EPOCHS,
          validation_data=testloader,
          callbacks=[WandbCallback(),
                     earlystopper])  

# Evaluate model on test set
loss, acc = model.evaluate(testloader)
wandb.log({'Test Accuracy': round(acc, 3)})

# Close W&B run
run.finish()
# Out:
#                 Tracking run with wandb version 0.10.21<br/>
#                 Syncing run <strong style="color:#cdcd00">stilted-night-76</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ayush-thakur/nfnet" target="_blank">https://wandb.ai/ayush-thakur/nfnet</a><br/>
#                 Run page: <a href="https://wandb.ai/ayush-thakur/nfnet/runs/gsnczo22" target="_blank">https://wandb.ai/ayush-thakur/nfnet/runs/gsnczo22</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210305_130100-gsnczo22</code><br/><br/>
# Epoch 1/100
#   6/782 [..............................] - ETA: 18s - loss: 2.3360 - acc: 0.1046WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0103s vs `on_train_batch_end` time: 0.0131s). Check your callbacks.
# 782/782 [==============================] - 14s 16ms/step - loss: 1.7273 - acc: 0.3354 - val_loss: 1.9676 - val_acc: 0.3384
# Epoch 2/100
# 782/782 [==============================] - 12s 16ms/step - loss: 1.1733 - acc: 0.5781 - val_loss: 1.6169 - val_acc: 0.4601
# Epoch 3/100
# 782/782 [==============================] - 12s 16ms/step - loss: 1.0175 - acc: 0.6369 - val_loss: 1.3602 - val_acc: 0.5161
# Epoch 4/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.9056 - acc: 0.6772 - val_loss: 1.2052 - val_acc: 0.5900
# Epoch 5/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.8461 - acc: 0.7030 - val_loss: 1.5486 - val_acc: 0.5400
# Epoch 6/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.7949 - acc: 0.7220 - val_loss: 0.9141 - val_acc: 0.6906
# Epoch 7/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.7540 - acc: 0.7399 - val_loss: 0.8572 - val_acc: 0.7085
# Epoch 8/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.7237 - acc: 0.7502 - val_loss: 0.9650 - val_acc: 0.6800
# Epoch 9/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6910 - acc: 0.7593 - val_loss: 1.0433 - val_acc: 0.6637
# Epoch 10/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6724 - acc: 0.7681 - val_loss: 0.9152 - val_acc: 0.7030
# Epoch 11/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6460 - acc: 0.7761 - val_loss: 1.4141 - val_acc: 0.6112
# Epoch 12/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6312 - acc: 0.7809 - val_loss: 1.2623 - val_acc: 0.6290
# Epoch 13/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.6149 - acc: 0.7879 - val_loss: 0.9506 - val_acc: 0.7049
# Epoch 14/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.6094 - acc: 0.7881 - val_loss: 1.0090 - val_acc: 0.6918
# Epoch 15/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5879 - acc: 0.7988 - val_loss: 0.7667 - val_acc: 0.7472
# Epoch 16/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5776 - acc: 0.8010 - val_loss: 0.9730 - val_acc: 0.6934
# Epoch 17/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5663 - acc: 0.8044 - val_loss: 0.8336 - val_acc: 0.7300
# Epoch 18/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5553 - acc: 0.8085 - val_loss: 0.8238 - val_acc: 0.7328
# Epoch 19/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5374 - acc: 0.8166 - val_loss: 0.9154 - val_acc: 0.7174
# Epoch 20/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.5382 - acc: 0.8141 - val_loss: 0.8197 - val_acc: 0.7371
# Epoch 21/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5320 - acc: 0.8162 - val_loss: 0.8667 - val_acc: 0.7259
# Epoch 22/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5194 - acc: 0.8222 - val_loss: 0.9747 - val_acc: 0.7103
# Epoch 23/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5110 - acc: 0.8226 - val_loss: 0.7551 - val_acc: 0.7557
# Epoch 24/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5036 - acc: 0.8295 - val_loss: 0.9249 - val_acc: 0.7138
# Epoch 25/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.5024 - acc: 0.8250 - val_loss: 0.9970 - val_acc: 0.7014
# Epoch 26/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.4897 - acc: 0.8341 - val_loss: 1.0505 - val_acc: 0.6883
# Epoch 27/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4768 - acc: 0.8366 - val_loss: 1.2033 - val_acc: 0.6655
# Epoch 28/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.4858 - acc: 0.8332 - val_loss: 1.0395 - val_acc: 0.6932
# Epoch 29/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4694 - acc: 0.8409 - val_loss: 0.8384 - val_acc: 0.7364
# Epoch 30/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4575 - acc: 0.8441 - val_loss: 0.9080 - val_acc: 0.7282
# Epoch 31/100
# 782/782 [==============================] - 13s 16ms/step - loss: 0.4588 - acc: 0.8411 - val_loss: 0.9253 - val_acc: 0.7282
# Epoch 32/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4441 - acc: 0.8473 - val_loss: 0.9415 - val_acc: 0.7242
# Epoch 33/100
# 782/782 [==============================] - 12s 16ms/step - loss: 0.4443 - acc: 0.8464 - val_loss: 0.9042 - val_acc: 0.7270
# 157/157 [==============================] - 1s 5ms/step - loss: 0.7551 - acc: 0.7557
# <br/>Waiting for W&B process to finish, PID 369<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.54MB of 0.54MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210305_130100-gsnczo22/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210305_130100-gsnczo22/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>32</td></tr><tr><td>loss</td><td>0.43417</td></tr><tr><td>acc</td><td>0.84938</td></tr><tr><td>val_loss</td><td>0.90423</td></tr><tr><td>val_acc</td><td>0.727</td></tr><tr><td>_runtime</td><td>421</td></tr><tr><td>_timestamp</td><td>1614949681</td></tr><tr><td>_step</td><td>33</td></tr><tr><td>best_val_loss</td><td>0.75512</td></tr><tr><td>best_epoch</td><td>22</td></tr><tr><td>Test Accuracy</td><td>0.756</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>acc</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>val_loss</td><td>█▆▄▄▆▂▂▂▃▂▅▄▂▂▁▂▁▁▂▁▂▂▁▂▂▃▄▃▁▂▂▂▂</td></tr><tr><td>val_acc</td><td>▁▃▄▅▄▇▇▇▆▇▆▆▇▇█▇██▇██▇█▇▇▇▆▇███▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>Test Accuracy</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 2 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">stilted-night-76</strong>: <a href="https://wandb.ai/ayush-thakur/nfnet/runs/gsnczo22" target="_blank">https://wandb.ai/ayush-thakur/nfnet/runs/gsnczo22</a><br/>

# %% [markdown]
# ![img](https://i.imgur.com/4KIoQ8C.png)
